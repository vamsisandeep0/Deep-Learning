# %% [markdown]
# **LeNet**

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# LeNet-5 architecture adapted for CIFAR-10
model = models.Sequential()
# C1 Convolutional Layer
model.add(layers.Conv2D(filters=6, kernel_size=(5, 5), activation='relu', input_shape=(32, 32, 3)))
# S2 Pooling Layer
model.add(layers.AveragePooling2D())
# C3 Convolutional Layer
model.add(layers.Conv2D(filters=16, kernel_size=(5, 5), activation='relu'))
# S4 Pooling Layer
model.add(layers.AveragePooling2D())
# C5 Fully Connected Convolutional Layer
model.add(layers.Conv2D(filters=120, kernel_size=(5, 5), activation='relu'))
# Flattening Layer
model.add(layers.Flatten())
# FC6 Fully Connected Layer
model.add(layers.Dense(units=84, activation='relu'))
#Output Layer
model.add(layers.Dense(units=10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Model summary
model.summary()

# Train the model
history = model.fit(train_images, train_labels, epochs=10,
                    validation_data=(test_images, test_labels))

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# ...
# 170498071/170498071 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 28, 28, 6)         456
#
#  average_pooling2d (Average  (None, 14, 14, 6)         0
#  Pooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_1 (Avera  (None, 5, 5, 16)          0
#  gePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 120)         48120
#
#  flatten (Flatten)           (None, 120)               0
#
#  dense (Dense)               (None, 84)                10164
#
#  dense_1 (Dense)             (None, 10)                850
#
# ...
# Total params: 62006 (242.21 KB)
# Trainable params: 62006 (242.21 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# ...

# %% [markdown]
# **LeNet**

# %% [markdown]
# The LeNet-5 Convolutional Neural Network (CNN) architecture, adapted for the CIFAR-10 dataset. The CIFAR-10 dataset, which consists of 60,000 color images in 10 classes, is loaded and normalized so that pixel values are between 0 and 1. The model is defined with the following layers: a convolutional layer with 6 filters and a kernel size of 5x5, followed by average pooling, another convolutional layer with 16 filters, another average pooling layer, a fully connected convolutional layer with 120 filters, a flattening layer, a fully connected layer with 84 units, and finally an output layer with 10 units and softmax activation.
#
# The model is compiled using the Adam optimizer and sparse categorical crossentropy loss function. It is trained on the training dataset for 10 epochs, with the test dataset used for validation. The model's accuracy and loss during training and validation are plotted over the epochs, providing a visual representation of the model's performance. The summary of the model is also displayed, showing the architecture and parameters of each layer.

# %% [markdown]
# **Sequential CNN architecture**

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# Define the CNN architecture
model = models.Sequential()

# Convolutional layer 1
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Convolutional layer 2
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Convolutional layer 3
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Flattening the output
model.add(layers.Flatten())

# Dense layer
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))

# Output layer
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Model summary
model.summary()

# Train the model
history = model.fit(train_images, train_labels, epochs=20,
                    validation_data=(test_images, test_labels))

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 128)               65664
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# ...

# %% [markdown]
# **Sequential CNN architecture**

# %% [markdown]
# Convolutional Neural Network (CNN) for classifying images from the CIFAR-10 dataset, which consists of 60,000 32x32 color images in 10 classes. The images are preprocessed by normalizing the pixel values to be between 0 and 1. The CNN architecture is defined as follows:
#
# Convolutional Layer 1: 32 filters of size 3x3, ReLU activation, followed by 2x2 max pooling and a dropout layer with a rate of 0.25 to reduce overfitting. Convolutional Layer 2: 64 filters of size 3x3, ReLU activation, followed by 2x2 max pooling and a dropout layer with a rate of 0.25. Convolutional Layer 3: 128 filters of size 3x3, ReLU activation, followed by 2x2 max pooling and a dropout layer with a rate of 0.25. Flattening: The output from the convolutional layers is flattened to a 1D vector to be fed into the dense layers. Dense Layer: A fully connected layer with 128 neurons and ReLU activation, followed by a dropout layer with a rate of 0.5. Output Layer: A fully connected layer with 10 neurons (one for each class) and softmax activation to output probabilities for each class. The model is compiled with the Adam optimizer, sparse categorical crossentropy loss function, and accuracy as the metric. It is trained for 20 epochs with the training dataset, and the validation dataset is used to monitor performance. After training, the model's accuracy and loss are plotted for both the training and validation sets to visualize the learning process and evaluate the model's performance.

# %% [markdown]
# **LeNet Hyperparameter Tuning**

# %%
# !pip install keras-tuner
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
import matplotlib.pyplot as plt

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

def build_model(hp):
    model = models.Sequential()
    model.add(layers.Conv2D(6, (5, 5), activation='relu', input_shape=(32, 32, 3)))
    model.add(layers.AveragePooling2D())
    model.add(layers.Conv2D(16, (5, 5), activation='relu'))
    model.add(layers.AveragePooling2D())
    model.add(layers.Conv2D(120, (5, 5), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(units=hp.Int('units', min_value=32, max_value=128, step=32), activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))

    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,  # Set the number of models to try
    executions_per_trial=1,
    directory='my_dir',
    project_name='helloworld')

tuner.search_space_summary()

tuner.search(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")

# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(train_images, train_labels, epochs=50, validation_data=(test_images, test_labels))

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Trial 10 Complete [00h 01m 26s]
# val_accuracy: 0.6288999915122986
#
# Best val_accuracy So Far: 0.6288999915122986
# Total elapsed time: 00h 13m 43s
#
# The hyperparameter search is complete. The optimal number of units in the densely-connected
# layer is 64 and the optimal learning rate for the optimizer
# is 0.001.
#
# Epoch 1/50
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.6836 - accuracy: 0.3819 - val_loss: 1.4893 - val_accuracy: 0.4555
# Epoch 2/50
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4199 - accuracy: 0.4850 - val_loss: 1.3324 - val_accuracy: 0.5166
# Epoch 3/50
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3122 - accuracy: 0.5289 - val_loss: 1.3737 - val_accuracy: 0.5028
# Epoch 4/50
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.2461 - accuracy: 0.5541 - val_loss: 1.2349 - val_accuracy: 0.5529
# Epoch 5/50
# ...

# %% [markdown]
# **LeNet Hyperparameter Tuning**

# %% [markdown]
# We used TensorFlow and Keras to build a convolutional neural network (CNN) for image classification on the CIFAR-10 dataset. The code normalizes the dataset, sets up a CNN architecture, and employs a hyperparameter tuning framework (Keras Tuner) to find the best model configuration. It then retrains the best model over 50 epochs, tracks its accuracy, and visualizes the results. The CNN has multiple convolutional and pooling layers, a dense layer whose size is optimized, and uses the Adam optimizer.

# %% [markdown]
# **ResNet**

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import numpy as np

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# Define a function for a ResNet identity block
def identity_block(x, filters):
    x_skip = x
    x = layers.Conv2D(filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)

    # Add shortcut
    x = layers.add([x, x_skip])
    x = layers.Activation('relu')(x)
    return x

# Define a function to create a Conv Block with stride 2
def conv_block(x, filters):
    x_skip = x
    x = layers.Conv2D(filters, (3, 3), padding='same', strides=2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)

    # Match dimensions for shortcut
    x_skip = layers.Conv2D(filters, (1, 1), strides=2)(x_skip)

    # Add shortcut
    x = layers.add([x, x_skip])
    x = layers.Activation('relu')(x)
    return x

# Define the overall ResNet architecture for CIFAR-10
input_layer = layers.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, (3, 3), padding='same')(input_layer)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = identity_block(x, 32)
x = conv_block(x, 64)
x = identity_block(x, 64)
x = conv_block(x, 128)
x = identity_block(x, 128)

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output_layer = layers.Dense(10, activation='softmax')(x)

model = models.Model(inputs=input_layer, outputs=output_layer)

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# Train the model
history = model.fit(train_images, train_labels, epochs=20, validation_data=(test_images, test_labels))

# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)           896       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 32)           128       ['conv2d_6[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 32)           0         ['batch_normalization[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)           9248      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)           128       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
# ...

# %% [markdown]
# **ResNet**

# %% [markdown]
#  In ResNet architecture we used TensorFlow and Keras for classifying CIFAR-10 images. The code includes normalization of image data, definitions of ResNet identity and convolutional blocks with skip connections for deeper network training without vanishing gradients. The model, compiled with the Adam optimizer and sparse categorical cross-entropy loss, trains 20 epochs and evaluates test data. It uses global average pooling, a dense layer, and dropout for regularization before a softmax output layer for classification.

# %% [markdown]
# **ResNet Hyperparameter Tuning**

# %%
# !pip install keras-tuner
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras import Input
from kerastuner import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

def build_model(hp):
    input_layer = Input(shape=(32, 32, 3))
    x = layers.Conv2D(hp.Choice('num_filters_1', values=[32, 64]), (3, 3), padding='same')(input_layer)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(hp.Choice('num_filters_2', values=[32, 64]), (3, 3), padding='same', strides=2)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(hp.Int('dense_units', min_value=128, max_value=512, step=128), activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output_layer = layers.Dense(10, activation='softmax')(x)

    model = models.Model(inputs=input_layer, outputs=output_layer)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
        ),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=1,
    directory='my_dir',
    project_name='cifar10_resnet'
)

tuner.search_space_summary()

# Perform hyperparameter search
tuner.search(train_images, train_labels, epochs=10, validation_split=0.1)

# Get the best model
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"Best hyperparameters:\n{best_hyperparameters.values}")

# Evaluate the best model
test_loss, test_acc = best_model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# Trial 10 Complete [00h 01m 26s]
# val_accuracy: 0.5333999991416931
#
# Best val_accuracy So Far: 0.5645999908447266
# Total elapsed time: 00h 13m 39s
# Best hyperparameters:
# {'num_filters_1': 32, 'num_filters_2': 64, 'dense_units': 512, 'learning_rate': 0.001}
# 313/313 [==============================] - 1s 4ms/step - loss: 1.2147 - accuracy: 0.5550
# Test accuracy: 0.555

# %% [markdown]
# **ResNet Hyperparameter Tuning**

# %% [markdown]
# We use TensorFlow and Keras with Keras Tuner to optimize a convolutional neural network's architecture for classifying CIFAR-10 images. We have defined a model building function with tunable hyperparameters for the number of convolution filters, dense layer units, and learning rate. Using RandomSearch, the script executes a hyperparameter search across different configurations, training each for 10 epochs. It then selectd the best model based on validation accuracy, evaluates it on test data, and reports the test accuracy and optimal hyperparameters.
